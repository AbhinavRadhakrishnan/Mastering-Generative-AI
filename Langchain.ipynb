# %% [markdown]
# Accessing different LLMs via LangChain

# %%
# !pip install -q -U langchain-community

# %% [markdown]
# Open AI

# %%
# !pip install -q -U langchain-openai

# %%
import os
from langchain_openai import ChatOpenAI

os.environ["OPENAI_API_KEY"]= "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"
llm = ChatOpenAI(
    model= "gpt-3.5-turbo-0125",
    temperature=0,
)

response = llm.invoke("what is Gen AI?")
print(response.content)

# %% [markdown]
# It is because i dont have an credits with me in my OPENAI account

# %% [markdown]
# GEMINI

# %%
# !pip install -q -U langchain-google-genai

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"]= "AIzaSyDtZ1lbG0oymH5QEnLYq7HxnDsE44yjUus"
llm = ChatGoogleGenerativeAI(
    model= "gemini-2.5-flash",
    temperature=0,
)

response = llm.invoke("what is Gen AI?")
print(response.content)
# Out:
# **Generative AI (Gen AI)** is a type of artificial intelligence that can **create new and original content** across various modalities, rather than just analyzing or classifying existing data.
#
# Here's a breakdown of what that means:
#
# 1.  **Generative:** The key word is "generative." Unlike traditional AI that might predict the next word, identify an object in an image, or classify an email as spam, Gen AI *generates* something entirely new. It doesn't just retrieve information; it synthesizes it.
#
# 2.  **Learning from Data:** Gen AI models are trained on **massive datasets** of existing content (text, images, audio, video, code, etc.). During this training, they learn the patterns, structures, styles, and relationships within that data.
#
# 3.  **Creating New Content:** Once trained, when given a **prompt** (a text instruction or input), the model uses its learned knowledge to produce output that is statistically similar to its training data but is unique and original.
#
# ...

# %% [markdown]
# Groq

# %%
pip install -q -U langchain-groq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"]= "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"
llm = ChatGroq(
    model= "llama-3.3-70b-versatile",
    temperature=0,
)

response = llm.invoke("what is Gen AI?")
print(response.content)
# Out:
# Gen AI, also known as General Artificial Intelligence or Strong AI, refers to a type of artificial intelligence that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks, similar to human intelligence. It is a hypothetical AI system that has the potential to perform any intellectual task that a human can.
#
# The key characteristics of Gen AI include:
#
# 1. **Generalizability**: The ability to apply knowledge and skills to various domains and tasks, not just a specific one.
# 2. **Reasoning and problem-solving**: The capacity to reason, solve problems, and make decisions like humans.
# 3. **Learning and adaptation**: The ability to learn from experience, adapt to new situations, and improve over time.
# 4. **Common sense**: The ability to understand the world in a way that is similar to human common sense.
# 5. **Autonomy**: The ability to operate independently, without human intervention.
#
# ...

# %% [markdown]
# OLLAMA

# %%
# !ollama list
# Out:
# NAME         ID              SIZE      MODIFIED
# gemma2:2b    8ccf136fdd52    1.6 GB    3 hours ago

# %%
# !pip install -q -U langchain-ollama

# %%
import os
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model= "gemma2:2b",
    temperature=0,
)

response = llm.invoke("what is Gen AI?")
print(response.content)
# Out:
# Gen AI, short for **Generative Artificial Intelligence**, refers to a type of artificial intelligence that focuses on creating new content.
#
# Here's a breakdown:
#
# **What it does:**
#
# * **Generates text, images, audio, video, and even code:** This means it can write stories, compose music, create artwork, design websites, and even build software programs.
# * **Learns from existing data:** Gen AI models are trained on massive datasets of text, images, and other information to understand patterns and relationships.
# * **Uses this knowledge to generate new content:** Based on the learned patterns, it can then create original outputs that resemble the training data but are unique in their own right.
#
# **Examples of Gen AI tools:**
#
# * **ChatGPT (text generation):**  Can write different kinds of creative text formats, like poems, code, scripts, musical pieces, email, letters, etc.
# * **DALL-E 2 (images):** Can create realistic and imaginative images from text descriptions.
# ...
